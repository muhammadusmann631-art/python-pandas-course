# %% [raw]
# pandas:
#       stats
#       query
#       clean
#       EdA
#       tansformation
#       datasets concat , merging
#       graphs
#       time series

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = sns.load_dataset("titanic")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
data.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
data.shape
# Out:
# (891, 15)

# %%
data.duplicated().sum()
# Out:
# 107

# %%
data.drop_duplicates(inplace=True)

# %%
data.rename(columns={"sex":"Gender"}, inplace=True)

# %%
data.drop(["sibsp","parch","embarked","adult_male","deck","alone"], axis=1, inplace=True)

# %%
data.drop(["pclass"],axis = 1, inplace=True)

# %%
x=data.Gender.value_counts().index
x
# Out:
# Index(['male', 'female'], dtype='object', name='Gender')

# %%
y=data.Gender.value_counts().values
y
# Out:
# array([491, 293], dtype=int64)

# %%
data.Gender.value_counts()
# Out:
# Gender
# male      491
# female    293
# Name: count, dtype: int64

# %%
sns.barplot(x=data.Gender.value_counts().index, y=data.Gender.value_counts().values, palette=["g","r"])
plt.show()

# %%
data
# Out:
#      survived  Gender   age     fare  class    who  embark_town alive
# 0           0    male  22.0   7.2500  Third    man  Southampton    no
# 1           1  female  38.0  71.2833  First  woman    Cherbourg   yes
# 2           1  female  26.0   7.9250  Third  woman  Southampton   yes
# 3           1  female  35.0  53.1000  First  woman  Southampton   yes
# 4           0    male  35.0   8.0500  Third    man  Southampton    no
# ..        ...     ...   ...      ...    ...    ...          ...   ...
# 885         0  female  39.0  29.1250  Third  woman   Queenstown    no
# 887         1  female  19.0  30.0000  First  woman  Southampton   yes
# 888         0  female   NaN  23.4500  Third  woman  Southampton    no
# 889         1    male  26.0  30.0000  First    man    Cherbourg   yes
# 890         0    male  32.0   7.7500  Third    man   Queenstown    no
#
# [784 rows x 8 columns]

# %%
sns.histplot(data.age, kde=True,color="y")
plt.show()

# %%
data["class"].value_counts()
# Out:
# class
# Third     405
# First     214
# Second    165
# Name: count, dtype: int64

# %%
plt.title("Class  Counts")
sns.countplot(x=data["class"], palette="rainbow")
plt.xlabel("Class name")
plt.ylabel("count of class")
plt.show()

# %%
data.embark_town.value_counts()
# Out:
# embark_town
# Southampton    568
# Cherbourg      155
# Queenstown      59
# Name: count, dtype: int64

# %%
data.embark_town.value_counts()
# Out:
# embark_town
# Southampton    568
# Cherbourg      155
# Queenstown      59
# Name: count, dtype: int64

# %%
x=data.embark_town.value_counts()
y=data.embark_town.value_counts().index
y
# Out:
# Index(['Southampton', 'Cherbourg', 'Queenstown'], dtype='object', name='embark_town')

# %%
plt.title("Pie Chart Of Embark_town",fontdict={"size":12, "color":"m"})
plt.pie(x=x, autopct="%.2f%%", labels=y,colors = ["y","g","b"])
plt.show()

# %%
sns.boxplot(data.age)
# Out:
# <Axes: >

# %%
data.embark_town.value_counts().plot(kind="line")
plt.show()

# %%
data.embark_town.value_counts().plot(kind="area", color = "y")
plt.show()

# %%
data.embark_town.value_counts().plot(kind="density", color = "y")
plt.show()
