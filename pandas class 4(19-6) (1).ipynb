# %%
import pandas as pd

# %% [markdown]
# ### EDA (exploartory data anylytics)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ###
#      -drop
#      -fill

# %%
fill
    --> hardcoded values
    --> mean
    --> median
    --->mode
# Out:
#   Cell In[81], line 2
#     --> hardcoded values
#     ^
# IndentationError: unexpected indent

# %%
data = pd.read_excel("employee.xlsx")
data
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 0        1    1101     Manager    Accounts  50.0  200000.0
# 1        2    1107     Officer          IT  30.0   80000.0
# 2        3    1203     Officer          HR  28.0       NaN
# 3        4    1005     Manager          HR  45.0  120000.0
# 4        5    2123  Office Boy    Accounts  27.0   45000.0
# 5        6    2451  Accountant         NaN  34.0  100000.0
# 6        7    1111  Accountant    Accounts   NaN  110000.0
# 7        8    1001     Officer          IT  25.0   75000.0
# 8        9    1234     Manager          IT  23.0       NaN
# 9       10    2156    Engineer  Production  45.0   89000.0
# 10      11    6543     Officer  Production  29.0  100000.0
# 11      12    3214  Accountant     Account  49.0  123000.0
# 12      13    2156    Engineer  Production  45.0   89000.0
# 13      14    1098     Officer          IT  25.0  100000.0
# 14      15    2912     Officer          IT  31.0   90000.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Serial       24 non-null     int64
#  1   Emp_ID       24 non-null     int64
#  2   Designation  24 non-null     object
#  3   Department   22 non-null     object
#  4   Age          23 non-null     float64
#  5   Salary       21 non-null     float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 1.3+ KB

# %%
data.columns
# Out:
# Index(['Serial', 'Emp_ID', 'Designation', 'Department', 'Age', 'Salary'], dtype='object')

# %%
data.shape
# Out:
# (24, 6)

# %%
data.isna().sum()
# Out:
# Serial         0
# Emp_ID         0
# Designation    0
# Department     2
# Age            1
# Salary         3
# dtype: int64

# %%
data.Designation.value_counts()
# Out:
# Designation
# Officer       9
# Accountant    5
# Engineer      5
# Manager       3
# Office Boy    2
# Name: count, dtype: int64

# %%
data.Age.min()
# Out:
# 23.0

# %%
data.Age.max()
# Out:
# 50.0

# %% [markdown]
# ### Dropna

# %%
axis 0 --> rows
axis 1 ---> columns
# Out:
#   Cell In[90], line 1
#     axis 0 --> rows
#          ^
# SyntaxError: invalid syntax

# %%
any = data mai aik bhi column ki rows nan mil gaye to pori rows drop kr den ga
all = sare columns ki rows main nan to drop krdey
# Out:
#   Cell In[91], line 1
#     any = data mai aik bhi column ki rows nan mil gaye to pori rows drop kr den ga
#                ^
# SyntaxError: invalid syntax

# %%
data.dropna(how="any")
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 0        1    1101     Manager    Accounts  50.0  200000.0
# 1        2    1107     Officer          IT  30.0   80000.0
# 3        4    1005     Manager          HR  45.0  120000.0
# 4        5    2123  Office Boy    Accounts  27.0   45000.0
# 7        8    1001     Officer          IT  25.0   75000.0
# 9       10    2156    Engineer  Production  45.0   89000.0
# 10      11    6543     Officer  Production  29.0  100000.0
# 11      12    3214  Accountant     Account  49.0  123000.0
# 12      13    2156    Engineer  Production  45.0   89000.0
# 13      14    1098     Officer          IT  25.0  100000.0
# 14      15    2912     Officer          IT  31.0   90000.0
# 16      17    2156    Engineer  Production  45.0   89000.0
# 17      18    2123  Office Boy    Accounts  27.0   45000.0
# 18      19    2156    Engineer  Production  45.0   89000.0
# 19      20    6543     Officer  Production  29.0  100000.0
# ...

# %%
data.isna().sum()
# Out:
# Serial         0
# Emp_ID         0
# Designation    0
# Department     2
# Age            1
# Salary         3
# dtype: int64

# %%
data.dropna(how="all")
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 0        1    1101     Manager    Accounts  50.0  200000.0
# 1        2    1107     Officer          IT  30.0   80000.0
# 2        3    1203     Officer          HR  28.0       NaN
# 3        4    1005     Manager          HR  45.0  120000.0
# 4        5    2123  Office Boy    Accounts  27.0   45000.0
# 5        6    2451  Accountant         NaN  34.0  100000.0
# 6        7    1111  Accountant    Accounts   NaN  110000.0
# 7        8    1001     Officer          IT  25.0   75000.0
# 8        9    1234     Manager          IT  23.0       NaN
# 9       10    2156    Engineer  Production  45.0   89000.0
# 10      11    6543     Officer  Production  29.0  100000.0
# 11      12    3214  Accountant     Account  49.0  123000.0
# 12      13    2156    Engineer  Production  45.0   89000.0
# 13      14    1098     Officer          IT  25.0  100000.0
# 14      15    2912     Officer          IT  31.0   90000.0
# ...

# %%
data.dropna(subset=["Designation","Age"])
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 0        1    1101     Manager    Accounts  50.0  200000.0
# 1        2    1107     Officer          IT  30.0   80000.0
# 2        3    1203     Officer          HR  28.0       NaN
# 3        4    1005     Manager          HR  45.0  120000.0
# 4        5    2123  Office Boy    Accounts  27.0   45000.0
# 5        6    2451  Accountant         NaN  34.0  100000.0
# 7        8    1001     Officer          IT  25.0   75000.0
# 8        9    1234     Manager          IT  23.0       NaN
# 9       10    2156    Engineer  Production  45.0   89000.0
# 10      11    6543     Officer  Production  29.0  100000.0
# 11      12    3214  Accountant     Account  49.0  123000.0
# 12      13    2156    Engineer  Production  45.0   89000.0
# 13      14    1098     Officer          IT  25.0  100000.0
# 14      15    2912     Officer          IT  31.0   90000.0
# 15      16    1222     Officer         NaN  25.0       NaN
# ...

# %% [markdown]
# ### Filter data

# %%
data.head()
# Out:
#    Serial  Emp_ID Designation Department   Age    Salary
# 0       1    1101     Manager   Accounts  50.0  200000.0
# 1       2    1107     Officer         IT  30.0   80000.0
# 2       3    1203     Officer         HR  28.0       NaN
# 3       4    1005     Manager         HR  45.0  120000.0
# 4       5    2123  Office Boy   Accounts  27.0   45000.0

# %%
data.Department.isna().sum()
# Out:
# 2

# %%
data.Department.fillna(0)  # fill with hardcouded values
# Out:
# 0       Accounts
# 1             IT
# 2             HR
# 3             HR
# 4       Accounts
# 5              0
# 6       Accounts
# 7             IT
# 8             IT
# 9     Production
# 10    Production
# 11       Account
# 12    Production
# 13            IT
# 14            IT
# 15             0
# 16    Production
# 17      Accounts
# 18    Production
# 19    Production
# 20       Account
# 21       Account
# 22    Production
# 23            IT
# Name: Department, dtype: object

# %%
data.Salary.fillna(8939339)    # fill with hardcouded values
# Out:
# 0      200000.0
# 1       80000.0
# 2     8939339.0
# 3      120000.0
# 4       45000.0
# 5      100000.0
# 6      110000.0
# 7       75000.0
# 8     8939339.0
# 9       89000.0
# 10     100000.0
# 11     123000.0
# 12      89000.0
# 13     100000.0
# 14      90000.0
# 15    8939339.0
# 16      89000.0
# 17      45000.0
# 18      89000.0
# 19     100000.0
# 20     123000.0
# 21     123000.0
# 22      89000.0
# 23     100000.0
# Name: Salary, dtype: float64

# %% [markdown]
# ###  mean, median, mode

# %% [markdown]
# categorical data:                        (MODE)  --. data ki reapeated values
#                 officer
#                 desintaion
#                 it
#                 hr
#                 department
#
#
#
#
# numerical data:        mean, median
#              4 4 4 44
#               4938.88

# %%
data.Department.mode()[0]
# Out:
# 'Production'

# %%
data.Department.fillna(data.Department.mode()[0])
# Out:
# 0       Accounts
# 1             IT
# 2             HR
# 3             HR
# 4       Accounts
# 5     Production
# 6       Accounts
# 7             IT
# 8             IT
# 9     Production
# 10    Production
# 11       Account
# 12    Production
# 13            IT
# 14            IT
# 15    Production
# 16    Production
# 17      Accounts
# 18    Production
# 19    Production
# 20       Account
# 21       Account
# 22    Production
# 23            IT
# Name: Department, dtype: object

# %%
data.Age.isna().sum()
# Out:
# 1

# %% [markdown]
# ###   mean
#             data ki values ki averge
#
#
# ##      median
#            [1,2,3,4,5,6]
#                 3.5

# %% [markdown]
# ### outliers
#       [ 10,20,25,30,40 ,`100]   ----> data mai outliers

# %%
import seaborn as sns
sns.boxplot(data.Age)
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.boxplot(data.Salary)
# Out:
# <Axes: >

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
outlier is far then filling data (median)
outlier is near then filling data (mean)

# %%
 5 table summary
         - min
         - mx
         - median
         - 25 percentiel
         - 50 percentiele

# %%
data.Age.mean()
# Out:
# 35.869565217391305

# %%
data.Salary.fillna(data.Salary.median(),inplace=True)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

# %%
np.n(data.Salary,25)
# Out:
# nan

# %%
import numpy as np

data1 = [10, 15, 20, 25, 30, 35, 40, 45, 50]
q1 = np.percentile(data1, 25)
print(q1)
# Out:
# 20.0

# %%
data
# Out:
# [10, 15, 20, 25, 30, 35, 40, 45, 50]

# %%
q1 = np.percentile(data.Salary,25)

# %%
q3 = np.percentile(data.Salary,75)

# %%
iqr = q3 - q1

# %%
iqr
# Out:
# 13500.0

# %%
lw = q1-1.5*iqr

# %%
hw = q3+1.5*iqr

# %%
lw
# Out:
# 68750.0

# %%
hw
# Out:
# 122750.0

# %% [markdown]
# ## Outlier data

# %%
data[(data.Salary<=lw) | (data.Salary>=hw)]
# Out:
#     Serial  Emp_ID Designation Department   Age    Salary
# 0        1    1101     Manager   Accounts  50.0  200000.0
# 4        5    2123  Office Boy   Accounts  27.0   45000.0
# 11      12    3214  Accountant    Account  49.0  123000.0
# 17      18    2123  Office Boy   Accounts  27.0   45000.0
# 20      21    3214  Accountant    Account  49.0  123000.0
# 21      22    3214  Accountant    Account  49.0  123000.0

# %% [markdown]
# ### clean salary data

# %%
data[~((data.Salary<=lw) | (data.Salary>=hw))]
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 1        2    1107     Officer          IT  30.0   80000.0
# 2        3    1203     Officer          HR  28.0  100000.0
# 3        4    1005     Manager          HR  45.0  120000.0
# 5        6    2451  Accountant         NaN  34.0  100000.0
# 6        7    1111  Accountant    Accounts   NaN  110000.0
# 7        8    1001     Officer          IT  25.0   75000.0
# 8        9    1234     Manager          IT  23.0  100000.0
# 9       10    2156    Engineer  Production  45.0   89000.0
# 10      11    6543     Officer  Production  29.0  100000.0
# 12      13    2156    Engineer  Production  45.0   89000.0
# 13      14    1098     Officer          IT  25.0  100000.0
# 14      15    2912     Officer          IT  31.0   90000.0
# 15      16    1222     Officer         NaN  25.0  100000.0
# 16      17    2156    Engineer  Production  45.0   89000.0
# 18      19    2156    Engineer  Production  45.0   89000.0
# ...

# %%
df=pd.read_excel("employee.xlsx")

# %%
df.fillna({ "Department" : df.Department.mode()[0],
    "Salary" :  df.Salary.median(),
    "Age" :  df.Age.mean()
}, inplace=True)

# %%
df.head()
# Out:
#    Serial  Emp_ID Designation Department   Age    Salary
# 0       1    1101     Manager   Accounts  50.0  200000.0
# 1       2    1107     Officer         IT  30.0   80000.0
# 2       3    1203     Officer         HR  28.0  100000.0
# 3       4    1005     Manager         HR  45.0  120000.0
# 4       5    2123  Office Boy   Accounts  27.0   45000.0

# %%
car_data

# %%
car_data = pd.read_csv("car_data.csv")

# %%
car_data.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
car_data.shape
# Out:
# (892, 6)

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
car_data.columns
# Out:
# Index(['name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type'], dtype='object')

# %% [markdown]
# ### Dupliacted

# %%
car_data.duplicated().sum()
# Out:
# 94

# %%
car_data[car_data.duplicated()]
# Out:
#                                      name   company  year     Price  \
# 14   Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007    80,000
# 15                Mahindra Jeep CL550 MDI  Mahindra  2006  4,25,000
# 20                   Mahindra Scorpio S10  Mahindra  2016  3,50,000
# 24                 Hyundai i20 Sportz 1.2   Hyundai  2012  1,00,000
# 25                 Hyundai i20 Sportz 1.2   Hyundai  2012  1,00,000
# ..                                    ...       ...   ...       ...
# 626               Tata Sumo Gold EX BS IV      Tata  2012  2,10,000
# 641         Maruti Suzuki Swift VDi BS IV    Maruti  2012  2,80,000
# 727                   Mahindra Scorpio S4  Mahindra  2015  8,65,000
# 861            Hyundai Getz Prime 1.3 GLX   Hyundai  2009  1,15,000
# 880    Maruti Suzuki Swift Dzire Tour VDi    Maruti  2009  2,50,000
#
#      kms_driven fuel_type
# 14   45,000 kms    Petrol
# 15       40 kms    Diesel
# 20   43,000 kms    Diesel
# 24   55,000 kms    Petrol
# ...

# %%
car_data[car_data.duplicated(subset=["name","company"])]
# Out:
#                                      name   company  year          Price  \
# 5        Ford EcoSport Titanium 1.5L TDCi      Ford  2015  Ask For Price
# 14   Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 15                Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 20                   Mahindra Scorpio S10  Mahindra  2016       3,50,000
# 21                   Mahindra Scorpio S10  Mahindra  2016       3,10,000
# ..                                    ...       ...   ...            ...
# 876                   Maruti Suzuki Dzire    Maruti  2016       4,50,000
# 879         Maruti Suzuki Alto LXi BS III    Maruti  2005         95,000
# 880    Maruti Suzuki Swift Dzire Tour VDi    Maruti  2009       2,50,000
# 886                  Toyota Corolla Altis    Toyota  2009       3,00,000
# 889                    Mahindra Quanto C8  Mahindra  2013       3,90,000
#
#        kms_driven fuel_type
# 5      59,000 kms    Diesel
# 14     45,000 kms    Petrol
# ...

# %%
data.loc[867,"name"]
# Out:
# 'Mahindra Quanto C4'

# %%
data.drop_duplicates(inplace=True)

# %%
data.name
# Out:
# 0        Hyundai Santro Xing XO eRLX Euro III
# 1                     Mahindra Jeep CL550 MDI
# 2                  Maruti Suzuki Alto 800 Vxi
# 3      Hyundai Grand i10 Magna 1.2 Kappa VTVT
# 4            Ford EcoSport Titanium 1.5L TDCi
#                         ...
# 887                                        Ta
# 888                       Tata Zest XM Diesel
# 889                        Mahindra Quanto C8
# 890                  Honda Amaze 1.2 E i VTEC
# 891                 Chevrolet Sail 1.2 LT ABS
# Name: name, Length: 798, dtype: object

# %%
data.head(3)
# Out:
#                                    name   company  year          Price  \
# 0  Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1               Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2            Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol

# %%
"name and ali".split().jo
# Out:
# ['name', 'and', 'ali']

# %%
car_data.name.str.split().str[0:4].str.join(" ")
# Out:
# 0           Hyundai Santro Xing XO
# 1          Mahindra Jeep CL550 MDI
# 2           Maruti Suzuki Alto 800
# 3          Hyundai Grand i10 Magna
# 4      Ford EcoSport Titanium 1.5L
#                   ...
# 887                             Ta
# 888            Tata Zest XM Diesel
# 889             Mahindra Quanto C8
# 890              Honda Amaze 1.2 E
# 891          Chevrolet Sail 1.2 LT
# Name: name, Length: 892, dtype: object

# %%
data.loc[887,"name"]
# Out:
# 'Ta'
