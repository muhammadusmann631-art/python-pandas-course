# %%
import pandas as pd

# %%
data = pd.read_excel("employee.xlsx")

# %%
data.head(2)
# Out:
#    Serial  Emp_ID Designation Department   Age    Salary
# 0       1    1101     Manager   Accounts  50.0  200000.0
# 1       2    1107     Officer         IT  30.0   80000.0

# %% [markdown]
# ## Dealing Rows

# %%
data = pd.read_excel("employee.xlsx",index_col="Serial")

# %%
data[2:5]
# Out:
#         Emp_ID Designation Department   Age    Salary
# Serial
# 3         1203     Officer         HR  28.0       NaN
# 4         1005     Manager         HR  45.0  120000.0
# 5         2123  Office Boy   Accounts  27.0   45000.0

# %%
data[[2:5,1:]]
# Out:
#   Cell In[22], line 1
#     data[[2:5,1:]]
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### iloc or loc

# %%
iloc  ---> integher loc

# %%
    r     s:e col  s :e
data.iloc[2:5,     1:4]
# Out:
#        Designation Department   Age
# Serial
# 3          Officer         HR  28.0
# 4          Manager         HR  45.0
# 5       Office Boy   Accounts  27.0

# %%
data.iloc[1:11, 3:4]
# Out:
#     Department
# 1           IT
# 2           HR
# 3           HR
# 4     Accounts
# 5          NaN
# 6     Accounts
# 7           IT
# 8           IT
# 9   Production
# 10  Production

# %%
# location
data.loc[0:6,"Emp_ID":"Department"]
# Out:
#    Emp_ID Designation Department
# 0    1101     Manager   Accounts
# 1    1107     Officer         IT
# 2    1203     Officer         HR
# 3    1005     Manager         HR
# 4    2123  Office Boy   Accounts
# 5    2451  Accountant        NaN
# 6    1111  Accountant   Accounts

# %%
data.loc[2:7,"Emp_ID":]
# Out:
#    Emp_ID Designation Department   Age    Salary
# 2    1203     Officer         HR  28.0       NaN
# 3    1005     Manager         HR  45.0  120000.0
# 4    2123  Office Boy   Accounts  27.0   45000.0
# 5    2451  Accountant        NaN  34.0  100000.0
# 6    1111  Accountant   Accounts   NaN  110000.0
# 7    1001     Officer         IT  25.0   75000.0

# %%
data[data.Designation=="Manager"]
# Out:
#    Serial  Emp_ID Designation Department   Age    Salary
# 0       1    1101     Manager   Accounts  50.0  200000.0
# 3       4    1005     Manager         HR  45.0  120000.0
# 8       9    1234     Manager         IT  23.0       NaN

# %%
data.Designation[data.Designation=="Manager"]
# Out:
# 0    Manager
# 3    Manager
# 8    Manager
# Name: Designation, dtype: object

# %%
data[data.Salary<=100000.0]
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 1        2    1107     Officer          IT  30.0   80000.0
# 4        5    2123  Office Boy    Accounts  27.0   45000.0
# 5        6    2451  Accountant         NaN  34.0  100000.0
# 7        8    1001     Officer          IT  25.0   75000.0
# 9       10    2156    Engineer  Production  45.0   89000.0
# 10      11    6543     Officer  Production  29.0  100000.0
# 12      13    2156    Engineer  Production  45.0   89000.0
# 13      14    1098     Officer          IT  25.0  100000.0
# 14      15    2912     Officer          IT  31.0   90000.0
# 16      17    2156    Engineer  Production  45.0   89000.0
# 17      18    2123  Office Boy    Accounts  27.0   45000.0
# 18      19    2156    Engineer  Production  45.0   89000.0
# 19      20    6543     Officer  Production  29.0  100000.0
# 22      23    2156    Engineer  Production  45.0   89000.0
# 23      24    1098     Officer          IT  25.0  100000.0

# %%
data[data.Age==25]
# Out:
#     Serial  Emp_ID Designation Department   Age    Salary
# 7        8    1001     Officer         IT  25.0   75000.0
# 13      14    1098     Officer         IT  25.0  100000.0
# 15      16    1222     Officer        NaN  25.0       NaN
# 23      24    1098     Officer         IT  25.0  100000.0

# %%
data[data.Designation=="Officer"]["Age"]
# Out:
# 1     30.0
# 2     28.0
# 7     25.0
# 10    29.0
# 13    25.0
# 14    31.0
# 15    25.0
# 19    29.0
# 23    25.0
# Name: Age, dtype: float64

# %%
data[data.Designation=="Officer"]["Department"]
# Out:
# 1             IT
# 2             HR
# 7             IT
# 10    Production
# 13            IT
# 14            IT
# 15           NaN
# 19    Production
# 23            IT
# Name: Department, dtype: object

# %%
data[(data.Designation=="Officer")& (data.Department=="HR")]
# Out:
#    Serial  Emp_ID Designation Department   Age  Salary
# 2       3    1203     Officer         HR  28.0     NaN

# %%
data.Salary.max()
# Out:
# 200000.0

# %%
data[data.Salary==200000.0]
# Out:
#    Serial  Emp_ID Designation Department   Age    Salary
# 0       1    1101     Manager   Accounts  50.0  200000.0

# %%
data[data.Salary==data.Salary.max()]
# Out:
#    Serial  Emp_ID Designation Department   Age    Salary
# 0       1    1101     Manager   Accounts  50.0  200000.0

# %%
python :   pandas
  or        |
  and       &

# %%
data[(data.Department=="IT")  | (data.Age==27)]
# Out:
#     Serial  Emp_ID Designation Department   Age    Salary
# 1        2    1107     Officer         IT  30.0   80000.0
# 4        5    2123  Office Boy   Accounts  27.0   45000.0
# 7        8    1001     Officer         IT  25.0   75000.0
# 8        9    1234     Manager         IT  23.0       NaN
# 13      14    1098     Officer         IT  25.0  100000.0
# 14      15    2912     Officer         IT  31.0   90000.0
# 17      18    2123  Office Boy   Accounts  27.0   45000.0
# 23      24    1098     Officer         IT  25.0  100000.0

# %%
data["colum_age_salary_multiply"] = data.Age*data.Salary

# %%
data[(data.Designation=="Officer")  & (data.Department=="IT")  &  (data.Age==28)]
# Out:
# Empty DataFrame
# Columns: [Serial, Emp_ID, Designation, Department, Age, Salary, colum_age_salary_multiply]
# Index: []

# %%
data[(data.Designation=="Officer")  & (data.Department=="HR")  &  (data.Age==28)]
# Out:
#    Serial  Emp_ID Designation Department   Age  Salary  \
# 2       3    1203     Officer         HR  28.0     NaN
#
#    colum_age_salary_multiply
# 2                        NaN

# %%
data.Designation
# Out:
# 0        Manager
# 1        Officer
# 2        Officer
# 3        Manager
# 4     Office Boy
# 5     Accountant
# 6     Accountant
# 7        Officer
# 8        Manager
# 9       Engineer
# 10       Officer
# 11    Accountant
# 12      Engineer
# 13       Officer
# 14       Officer
# 15       Officer
# 16      Engineer
# 17    Office Boy
# 18      Engineer
# 19       Officer
# 20    Accountant
# 21    Accountant
# 22      Engineer
# 23       Officer
# Name: Designation, dtype: object

# %% [markdown]
# ### MOvie Data

# %%
df=pd.read_csv("movie.csv")
df.head(12)
# Out:
#                                          Series_Title Released_Year  \
# 0                            The Shawshank Redemption          1994
# 1                                       The Godfather          1972
# 2                                     The Dark Knight          2008
# 3                              The Godfather: Part II          1974
# 4                                        12 Angry Men          1957
# 5       The Lord of the Rings: The Return of the King          2003
# 6                                        Pulp Fiction          1994
# 7                                    Schindler's List          1993
# 8                                           Inception          2010
# 9                                          Fight Club          1999
# 10  The Lord of the Rings: The Fellowship of the Ring          2001
# 11                                       Forrest Gump          1994
#
#    Certificate  Runtime                      Genre  IMDB_Rating  Meta_score  \
# ...

# %%
df.tail(10)
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 990            Giù la testa          1971          PG  157 min
# 991          Kelly's Heroes          1970          GP  144 min
# 992         The Jungle Book          1967           U   78 min
# 993                  Blowup          1966           A  111 min
# 994      A Hard Day's Night          1964           U   87 min
# 995  Breakfast at Tiffany's          1961           A  115 min
# 996                   Giant          1956           G  201 min
# 997   From Here to Eternity          1953      Passed  118 min
# 998                Lifeboat          1944         NaN   97 min
# 999            The 39 Steps          1935         NaN   86 min
#
#                             Genre  IMDB_Rating  Meta_score  \
# 990           Drama, War, Western          7.6        77.0
# 991        Adventure, Comedy, War          7.6        50.0
# 992  Animation, Adventure, Family          7.6        65.0
# ...

# %%
data.sample(3)
# Out:
#     Serial  Emp_ID Designation Department   Age   Salary  \
# 7        8    1001     Officer         IT  25.0  75000.0
# 14      15    2912     Officer         IT  31.0  90000.0
# 1        2    1107     Officer         IT  30.0  80000.0
#
#     colum_age_salary_multiply
# 7                   1875000.0
# 14                  2790000.0
# 1                   2400000.0

# %% [markdown]
# ### unique or nunique
