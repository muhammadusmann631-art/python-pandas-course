# %%
import pandas as pd

# %%
df = pd.read_csv('movie.csv')

# %%
df.head()
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  Meta_score              Director  \
# 0                 Drama          9.3        80.0        Frank Darabont
# 1          Crime, Drama          9.2       100.0  Francis Ford Coppola
# 2  Action, Crime, Drama          9.0        84.0     Christopher Nolan
# 3          Crime, Drama          9.0        90.0  Francis Ford Coppola
# 4          Crime, Drama          9.0        96.0          Sidney Lumet
#
#             Star1  No_of_Votes        Gross
# 0     Tim Robbins      2343110   28341469.0
# 1   Marlon Brando      1620367  134966411.0
# ...

# %%
df.tail()
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 995  Breakfast at Tiffany's          1961           A  115 min
# 996                   Giant          1956           G  201 min
# 997   From Here to Eternity          1953      Passed  118 min
# 998                Lifeboat          1944         NaN   97 min
# 999            The 39 Steps          1935         NaN   86 min
#
#                         Genre  IMDB_Rating  Meta_score          Director  \
# 995    Comedy, Drama, Romance          7.6        76.0     Blake Edwards
# 996            Drama, Western          7.6        84.0    George Stevens
# 997       Drama, Romance, War          7.6        85.0    Fred Zinnemann
# 998                Drama, War          7.6        78.0  Alfred Hitchcock
# 999  Crime, Mystery, Thriller          7.6        93.0  Alfred Hitchcock
#
#                  Star1  No_of_Votes       Gross
# 995     Audrey Hepburn       166544         NaN
# 996   Elizabeth Taylor        34075         NaN
# ...

# %%
df.sample(3)
# Out:
#            Series_Title Released_Year Certificate  Runtime  \
# 415                Jaws          1975           A  124 min
# 266  Dead Poets Society          1989           U  128 min
# 560       The Big Sleep          1946      Passed  114 min
#
#                          Genre  IMDB_Rating  Meta_score          Director  \
# 415        Adventure, Thriller          8.0        87.0  Steven Spielberg
# 266              Comedy, Drama          8.1        79.0        Peter Weir
# 560  Crime, Film-Noir, Mystery          7.9         NaN      Howard Hawks
#
#                Star1  No_of_Votes        Gross
# 415     Roy Scheider       543388  260000000.0
# 266   Robin Williams       425457   95860116.0
# 560  Humphrey Bogart        78796    6540000.0

# %% [markdown]
# ### Unique or nunique

# %%
usman, ali,ahmed, khan,usman,man,ali,usman,shahid,imran,imran,ubaid
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 usman, ali,ahmed, khan,usman,man,ali,usman,shahid,imran,imran,ubaid
#
# NameError: name 'usman' is not defined

# %% [markdown]
# ### Unique

# %%
usman,ali,ahmed,khan,shahid,imran,ubaid,man
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[132], line 1
# ----> 1 usman,ali,ahmed,khan,shahid,imran,ubaid,man
#
# NameError: name 'usman' is not defined

# %% [markdown]
# ### nuniaque

# %%
8

df.Series_Title.unique()

# %%
df.shape
# Out:
# (1000, 11)

# %%
df.Series_Title.nunique()
# Out:
# 999

# %%
df.Series_Title.value_counts()
# Out:
# Series_Title
# Drishyam                  2
# Cidade de Deus            1
# The Muppet Movie          1
# The Warriors              1
# Schindler's List          1
#                          ..
# Breakfast at Tiffany's    1
# Giant                     1
# From Here to Eternity     1
# Lifeboat                  1
# Falling Down              1
# Name: count, Length: 999, dtype: int64

# %%
df.Series_Title.isna().sum()
# Out:
# np.int64(0)

# %%
data:
     rows nan dekhna
     duplicate dekhna
     dtype dekhna
# Out:
#   Cell In[138], line 1
#     data:
#          ^
# SyntaxError: invalid syntax

# %%
df.Released_Year.unique()
# Out:
# array(['1994', '1972', '2008', '1974', '1957', '2003', '1993', '2010',
#        '1999', '2001', '1966', '2002', '1990', '1980', '1975', '2020',
#        '2019', '2014', '1998', '1997', '1995', '1991', '1977', '1962',
#        '1954', '1946', '2011', '2006', '2000', '1988', '1985', '1968',
#        '1960', '1942', '1936', '1931', '2018', '2017', '2016', '2012',
#        '2009', '2007', '1984', '1981', '1979', '1971', '1963', '1964',
#        '1950', '1940', '2013', '2005', '2004', '1992', '1987', '1986',
#        '1983', '1976', '1973', '1965', '1959', '1958', '1952', '1948',
#        '1944', '1941', '1927', '1921', '2015', '1996', '1989', '1978',
#        '1961', '1955', '1953', '1925', '1924', '1982', '1967', '1951',
#        '1949', '1939', '1937', '1934', '1928', '1926', '1920', '1970',
#        '1969', '1956', '1947', '1945', '1930', '1938', '1935', '1933',
#        '1932', '1922', '1943', 'PG'], dtype=object)

# %%
df.Released_Year.astype("int")

# %%
df[df.Released_Year=="PG"]
# Out:
#     Series_Title Released_Year Certificate  Runtime  \
# 966    Apollo 13            PG           U  140 min
#
#                          Genre  IMDB_Rating  Meta_score    Director  \
# 966  Adventure, Drama, History          7.6        77.0  Ron Howard
#
#          Star1  No_of_Votes        Gross
# 966  Tom Hanks       269197  173837933.0

# %%
df.Released_Year[df.Released_Year=="PG"] = 1980
# Out:
# C:\Users\Teacher PC\AppData\Local\Temp\ipykernel_9208\1810751736.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Released_Year[df.Released_Year=="PG"] = 1980

# %%
df.loc[966,"Released_Year"]
# Out:
# 1980

# %%
df[df.Released_Year=="PG"]
# Out:
# Empty DataFrame
# Columns: [Series_Title, Released_Year, Certificate, Runtime, Genre, IMDB_Rating, Meta_score, Director, Star1, No_of_Votes, Gross]
# Index: []

# %%
df.loc[966,"Released_Year"]
# Out:
# 1980

# %%
df.loc[966]
# Out:
# Series_Title                     Apollo 13
# Released_Year                         1980
# Certificate                              U
# Runtime                            140 min
# Genre            Adventure, Drama, History
# IMDB_Rating                            7.6
# Meta_score                            77.0
# Director                        Ron Howard
# Star1                            Tom Hanks
# No_of_Votes                         269197
# Gross                          173837933.0
# Name: 966, dtype: object

# %%
df.Released_Year.unique()
# Out:
# array(['1994', '1972', '2008', '1974', '1957', '2003', '1993', '2010',
#        '1999', '2001', '1966', '2002', '1990', '1980', '1975', '2020',
#        '2019', '2014', '1998', '1997', '1995', '1991', '1977', '1962',
#        '1954', '1946', '2011', '2006', '2000', '1988', '1985', '1968',
#        '1960', '1942', '1936', '1931', '2018', '2017', '2016', '2012',
#        '2009', '2007', '1984', '1981', '1979', '1971', '1963', '1964',
#        '1950', '1940', '2013', '2005', '2004', '1992', '1987', '1986',
#        '1983', '1976', '1973', '1965', '1959', '1958', '1952', '1948',
#        '1944', '1941', '1927', '1921', '2015', '1996', '1989', '1978',
#        '1961', '1955', '1953', '1925', '1924', '1982', '1967', '1951',
#        '1949', '1939', '1937', '1934', '1928', '1926', '1920', '1970',
#        '1969', '1956', '1947', '1945', '1930', '1938', '1935', '1933',
#        '1932', '1922', '1943', 1980], dtype=object)

# %%
df.Released_Year=df.Released_Year.astype("int")

# %%
df.Released_Year.dtypes
# Out:
# dtype('int64')

# %%
df.head()
# Out:
#                Series_Title  Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption           1994           A  142 min
# 1             The Godfather           1972           A  175 min
# 2           The Dark Knight           2008          UA  152 min
# 3    The Godfather: Part II           1974           A  202 min
# 4              12 Angry Men           1957           U   96 min
#
#                   Genre  IMDB_Rating  Meta_score              Director  \
# 0                 Drama          9.3        80.0        Frank Darabont
# 1          Crime, Drama          9.2       100.0  Francis Ford Coppola
# 2  Action, Crime, Drama          9.0        84.0     Christopher Nolan
# 3          Crime, Drama          9.0        90.0  Francis Ford Coppola
# 4          Crime, Drama          9.0        96.0          Sidney Lumet
#
#             Star1  No_of_Votes        Gross
# 0     Tim Robbins      2343110   28341469.0
# 1   Marlon Brando      1620367  134966411.0
# ...

# %%
df.Certificate.unique()
# Out:
# array(['A', 'UA', 'U', 'PG-13', 'R', nan, 'PG', 'G', 'Passed', 'TV-14',
#        '16', 'TV-MA', 'Unrated', 'GP', 'Approved', 'TV-PG', 'U/A'],
#       dtype=object)

# %%
df.Runtime.unique()

# %%
df.Runtime=df.Runtime.str.replace(" min","").astype(int)

# %%
df.Runtime
# Out:
# 0      142
# 1      175
# 2      152
# 3      202
# 4       96
#       ...
# 995    115
# 996    201
# 997    118
# 998     97
# 999     86
# Name: Runtime, Length: 1000, dtype: int64

# %%
df.loc[966]
# Out:
# Series_Title       1980
# Released_Year      1980
# Certificate        1980
# Runtime            1980
# Genre              1980
# IMDB_Rating      1980.0
# Meta_score       1980.0
# Director           1980
# Star1              1980
# No_of_Votes        1980
# Gross            1980.0
# Name: 966, dtype: object

# %%
3333

# %%
df.Genre.isna().sum()
# Out:
# np.int64(0)

# %%
df.Genre
# Out:
# 0                         Drama
# 1                  Crime, Drama
# 2          Action, Crime, Drama
# 3                  Crime, Drama
# 4                  Crime, Drama
#                  ...
# 995      Comedy, Drama, Romance
# 996              Drama, Western
# 997         Drama, Romance, War
# 998                  Drama, War
# 999    Crime, Mystery, Thriller
# Name: Genre, Length: 1000, dtype: object

# %%
df.IMDB_Rating.isna().sum()
# Out:
# np.int64(0)

# %%
df.IMDB_Rating.isnull().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Meta_score       157
# Director           0
# Star1              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
df.Meta_score.isna().sum()
# Out:
# np.int64(157)

# %%
df.Meta_score
# Out:
# 0       80.0
# 1      100.0
# 2       84.0
# 3       90.0
# 4       96.0
#        ...
# 995     76.0
# 996     84.0
# 997     85.0
# 998     78.0
# 999     93.0
# Name: Meta_score, Length: 1000, dtype: float64

# %%
df.Gross
# Out:
# 0       28341469.0
# 1      134966411.0
# 2      534858444.0
# 3       57300000.0
# 4        4360000.0
#           ...
# 995            NaN
# 996            NaN
# 997     30500000.0
# 998            NaN
# 999            NaN
# Name: Gross, Length: 1000, dtype: float64

# %% [markdown]
# ![image.png](attachment:7442f3dd-748b-4c9e-b870-4258f2b3c954.png)

# %%
ali zada Drama
Drama
monster
monter Drama

# %%
df[df.Released_Year>=2000]

# %%
df[df.IMDB_Rating>9]
# Out:
#                Series_Title  Released_Year Certificate  Runtime         Genre  \
# 0  The Shawshank Redemption           1994           A      142         Drama
# 1             The Godfather           1972           A      175  Crime, Drama
#
#    IMDB_Rating  Meta_score              Director          Star1  No_of_Votes  \
# 0          9.3        80.0        Frank Darabont    Tim Robbins      2343110
# 1          9.2       100.0  Francis Ford Coppola  Marlon Brando      1620367
#
#          Gross
# 0   28341469.0
# 1  134966411.0

# %% [markdown]
# ### how many movies are there for each genre?

# %%
df.Genre.value_counts()
# Out:
# Genre
# Drama                        85
# Drama, Romance               37
# Comedy, Drama                35
# Comedy, Drama, Romance       31
# Action, Crime, Drama         30
#                              ..
# Action, Adventure, Family     1
# Action, Crime, Mystery        1
# Animation, Drama, Romance     1
# Drama, War, Western           1
# Adventure, Comedy, War        1
# Name: count, Length: 202, dtype: int64

# %%
df[df.Director=="Christopher Nolan"]
# Out:
#               Series_Title  Released_Year Certificate  Runtime  \
# 2          The Dark Knight           2008          UA      152
# 8                Inception           2010          UA      148
# 21            Interstellar           2014          UA      169
# 36            The Prestige           2006           U      130
# 63   The Dark Knight Rises           2012          UA      164
# 69                 Memento           2000          UA      113
# 155          Batman Begins           2005          UA      140
# 573                Dunkirk           2017          UA      106
#
#                          Genre  IMDB_Rating  Meta_score           Director  \
# 2         Action, Crime, Drama          9.0        84.0  Christopher Nolan
# 8    Action, Adventure, Sci-Fi          8.8        74.0  Christopher Nolan
# 21    Adventure, Drama, Sci-Fi          8.6        74.0  Christopher Nolan
# 36      Drama, Mystery, Sci-Fi          8.5        66.0  Christopher Nolan
# ...

# %%
df.Director.value_counts()
# Out:
# Director
# Alfred Hitchcock    14
# Steven Spielberg    13
# Hayao Miyazaki      11
# Akira Kurosawa      10
# Martin Scorsese     10
#                     ..
# Kinji Fukasaku       1
# Eric Bress           1
# Thomas Kail          1
# Irvin Kershner       1
# Lana Wachowski       1
# Name: count, Length: 548, dtype: int64

# %%
df[df.Genre.str.contains("Drama")]
# Out:
#                  Series_Title  Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption           1994           A      142
# 1               The Godfather           1972           A      175
# 2             The Dark Knight           2008          UA      152
# 3      The Godfather: Part II           1974           A      202
# 4                12 Angry Men           1957           U       96
# ..                        ...            ...         ...      ...
# 993                    Blowup           1966           A      111
# 995    Breakfast at Tiffany's           1961           A      115
# 996                     Giant           1956           G      201
# 997     From Here to Eternity           1953      Passed      118
# 998                  Lifeboat           1944         NaN       97
#
#                         Genre  IMDB_Rating  Meta_score  \
# 0                       Drama          9.3        80.0
# 1                Crime, Drama          9.2       100.0
# ...

# %% [markdown]
# ![image.png](attachment:d7dcb7b9-a88f-4558-a0e5-d415eb620ae1.png)

# %%
df.sort_values(by="IMDB_Rating",ascending=False)
# Out:
#                  Series_Title  Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption           1994           A      142
# 1               The Godfather           1972           A      175
# 4                12 Angry Men           1957           U       96
# 2             The Dark Knight           2008          UA      152
# 3      The Godfather: Part II           1974           A      202
# ..                        ...            ...         ...      ...
# 995    Breakfast at Tiffany's           1961           A      115
# 996                     Giant           1956           G      201
# 997     From Here to Eternity           1953      Passed      118
# 998                  Lifeboat           1944         NaN       97
# 999              The 39 Steps           1935         NaN       86
#
#                         Genre  IMDB_Rating  Meta_score              Director  \
# 0                       Drama          9.3        80.0        Frank Darabont
# ...

# %%
df[df.Runtime==df.Runtime.max()]
# Out:
#            Series_Title  Released_Year Certificate  Runtime  \
# 140  Gangs of Wasseypur           2012           A      321
#
#                      Genre  IMDB_Rating  Meta_score        Director  \
# 140  Action, Comedy, Crime          8.2        89.0  Anurag Kashyap
#
#               Star1  No_of_Votes  Gross
# 140  Manoj Bajpayee        82365    NaN

# %%
df.IMDB_Rating.mean()
# Out:
# np.float64(7.949299999999999)

# %% [markdown]
# ### kon is movie aisi thi jo 2010 aur 2014 kai  bech mai realease hwi  thi

# %%
df[(df.Released_Year>=2010) & (df.Released_Year <=2014)]

# %%
df["random_number_genrate"]= np.random.randint(0,1000,1000)

# %%
df.columns
# Out:
# Index(['Series_Title', 'Released_Year', 'Certificate', 'Runtime', 'Genre',
#        'IMDB_Rating', 'Meta_score', 'Director', 'Star1', 'No_of_Votes',
#        'Gross', 'random_number_genrate'],
#       dtype='object')

# %%
np.random.randint(1000)
# Out:
# 58
